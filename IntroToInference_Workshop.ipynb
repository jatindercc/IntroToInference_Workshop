# %% [markdown]
# ![Image Description](./images/NormalityAndInferencing.png)

# %% [markdown]
# # Environment Setup
# ---
#
# - Start by creating a Virtual Environment for your project
#
# Before running any code in this notebook, it's important to set up a clean Python environment to manage dependencies. We recommend using a **VENV-type virtual environment** in **Visual Studio Code (VSC)**. Follow these steps:
#
# ### ✅ Steps to Create a Virtual Environment in VSC
#
# 1. **Open your project folder** in Visual Studio Code.
#
# 2. **Open the terminal**:
#    - Go to `View` > `Terminal` or press `Ctrl + `` (backtick).
#
# 3. **Create the virtual environment** by running:
#    ```bash
#    python -m venv venv
#    ```
#
# 4. Once the environment is created, you need to **activate it** so that all Python packages you install are scoped to this project only.
#     On Windows:
#     ```bash
#     .\venv\Scripts\activate
#     ```
#
#     On macOS/Linux
#     ```bash
#     source venv/bin/activate
#     ```
#
# 5. ⚠️ Why Activation Matters
# Activating the virtual environment ensures that:
#
# - All package installations using pip are local to your project.
# - You avoid modifying the global Python environment, which could affect other projects or system tools.
# - Your project remains portable and reproducible, especially when sharing with others or deploying.

# %% [markdown]
# ### 📦 Installing Required Libraries
# Once activated, install the required libraries using:

# %%
pip install -r requirements.txt

# %% [markdown]
# # 🎯 Accuracy vs. Precision
#
# ---
#
# ![Image Description](./images/AccuracyVsPrecision.png)
#
# <div style="display: flex;">
#     <div style="flex: 1; padding: 10px;">
#         <h2>Accuracy</h2>
#         <p><b>Definition:</b> Accuracy refers to how close a measurement or set of measurements is to the true or accepted value of the quantity being measured. It is about correctness.</p>
#         <p><b>Target Analogy:</b> In the context of a dartboard, accuracy is how close your darts land to the bullseye.</p>
#         <p><b>Statistical Measure:</b> Accuracy is often quantified by the <b>bias</b> of a measurement. A low bias indicates high accuracy. It can also be described by the mean error.</p>
#     </div>
#     <div style="flex: 1; padding: 10px;">
#         <h2>Precision</h2>
#         <p><b>Definition:</b> Precision refers to how close repeated measurements are to each other, regardless of whether they are close to the true value. It is about consistency and reproducibility.</p>
#         <p><b>Target Analogy:</b> On a dartboard, precision is how tightly clustered your darts are, even if they are far from the bullseye.</p>
#         <p><b>Statistical Measure:</b> Precision is typically quantified by the <b>spread</b> or <b>variability</b> of the measurements. Common statistical measures of precision include:</p>
#         <ul>
#             <li><b>Standard Deviation:</b> A measure of the average amount of variation or dispersion of a set of values. A smaller standard deviation indicates higher precision.</li>
#             <li><b>Variance:</b> The square of the standard deviation.</li>
#             <li><b>Range:</b> The difference between the highest and lowest values in a set of measurements.</li>
#         </ul>
#     </div>
# </div>

# %% [markdown]
# # 📊 Normalization and Standardization
#
#
# These two terms are fundamental to the Data Exploration phase of the ML Cycle, specifically when it comes to cleaning data.
#
# ![Image Description](./images/MachineLearningOperationsLifeCycle.png)
#
# ### Key concepts
#
# <table>
#   <tr>
#     <td style="vertical-align: top; padding-right: 20px;">
#         <img src="./images/NormalizationDefined.png">
#     </td>
#     <td style="vertical-align: top; padding-right: 20px;">
#         <img src="./images/StandardizationDefined.png">
#     </td>
#   </tr>
# </table>
#
# ### Principles
# ![Image Description](./images/NormalizationVsStandarization-1.png)
#
# ### Examples
#
# <table>
#   <tr>
#     <th>Normalization</th>
#     <th>Standardization</th>
#   </tr>
#   <tr>
#     <td style="vertical-align: top; padding-right: 20px;">
#         <img src="./images/NormalizationExample-1.png">
#     </td>
#     <td style="vertical-align: top; padding-right: 20px;">
#         <img src="./images/StandardizationExample-1.png">
#     </td>
#   </tr>
#   <tr>
#     <td style="vertical-align: top; padding-right: 20px;">
#         <img src="./images/NormalizationExample-2.png">
#     </td>
#     <td style="vertical-align: top; padding-right: 20px;">
#         <img src="./images/StandardizationExample-2.png">
#     </td>
#   </tr>
# </table>

# %% [markdown]
# # 🔔 Normality and Probability Distributions
#
#
# Experiment with the **Discrete and Continuous** simulator. Choose the **Continuous** class and then **Normal** from the list of distributions.

# %% [markdown]
# <table>
#   <tr>
#     <td style="vertical-align: top; padding-right: 20px;">
#       Go to Probablity Distributions > Discrete and Contiuous. <br>
#       Then hit the <b>Continuous</b> radio. <br>
#       Then, from the pull down meny, choose <b>Normal</b>
#     </td>
#   </tr>
#   <tr>
#     <td style="vertical-align: top; padding-right: 20px;">
#       <iframe
#         src="https://seeing-theory.brown.edu/probability-distributions/index.html?section2"
#         width="800"
#         height="400">
#       </iframe>
#     </td>
#     <td style="width: 200px; height: 400px">
#       <p>
#         When the mean (μ) is greater than 0 and the variance (σ²) is zero, all the data points are tightly clustered.<br><br>
#         When the mean (μ) is greater than 0 and the variance (σ²) is very large, the data points are spread far apart.
#       </p>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ## 📊 Z-distribution
#
# The standard normal distribution has **mean μ = 0** and **standard deviation σ = 1**.
# It is used to standardize data and calculate probabilities.
# Z-scores show how many standard deviations a value is from the mean.

# %% [markdown]
# <table>
#   <tr>
#     <td style="vertical-align: top; padding-right: 20px;">
#       <strong>Steps to Use the Simulator</strong><br><br>
#       1. Open the simulator below.<br>
#       2. Adjust the Z₁ and Z₂ sliders to set the bounds.<br>
#       3. Observe how the shaded area changes.<br>
#       4. Use the area value to interpret probability.<br>
#       5. Try different values to explore the distribution.
#     </td>
#   </tr>
#   <tr>
#     <td style="vertical-align: top; padding-right: 20px;">
#       <iframe
#         src="https://www.geogebra.org/m/zeF3hkXf"
#         width="800"
#         height="1000">
#       </iframe>
#     </td>
#     <td  style="vertical-align: top; padding-right: 20px; width: 100; height: 800;">
#       <p>
#         Z₁ and Z₂ define the lower and upper bounds on the standard normal curve.
#         The shaded area between them represents the probability of a value falling within that range.
#         A larger area means higher likelihood; a smaller area means lower probability.
#       </p>
#       <p>
#         The Z-score measures how many standard deviations a data point is from the mean of a dataset. It helps identify outliers and compare values across different distributions. A Z-score of 0 means the value is exactly at the mean, while positive or negative scores indicate how far above or below the mean the value lies.
#       </p>
#       <p>
# 📐 Z-Score
# The Z-score measures how many standard deviations a data point is from the mean.
# It helps identify outliers and compare values across different distributions.
# A Z-score of 0 means the value is at the mean; positive or negative scores show how far above or below the mean the value lies.
#
# **Formula:**
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# Where:
# - Z is the z-score,
# - X is the value of the element,
# - μ is the population mean, and
# - σ is the standard deviation.
#
# **Example:**
# In a class where the average score is 70 and the standard deviation is 10,
# a student scoring 85 has:
#
# $$
# Z = \frac{85 - 70}{10} = 1.5
# $$
# This means the score is 1.5 standard deviations above the mean.
#       </p>
#       <p>
#         Example: In a class where the average test score is 70 with a standard deviation of 10, a student scoring 85 has a Z-score of (85 - 70) / 10 = 1.5.This means the score is 1.5 standard deviations above the mean.
#       </p>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ### 📐 Z-Scores: Proportions & Reverse Lookups (Example: Student Score = 85)
#
#
# When we have a normal distribution (not standardized), say with mean $\mu$ and standard deviation $\sigma$, we often want to answer questions like:
#
# > *“What proportion (or percentage) of students score less than $X = 85$?”*
#
# This is where **standardization** with Z-scores comes in.
#
#
# #### 1. Standardization: Transforming to the Standard Normal
#
# The standard normal distribution has:
#
# - mean $0$ (denoted $\mu = 0$),
# - standard deviation $1$ (denoted $\sigma = 1$).
#
# We convert any normal variable $X$ with mean $\mu$ and standard deviation $\sigma$ into a **Z-score** via:
#
# $$
# Z = \frac{X - \mu}{\sigma}
# $$
#
# This transformation shifts and scales the variable so we can use standard normal tables or functions.
#
#
# #### 2. Example: Proportion Less Than a Value
#
# Suppose:
#
# - $X$ = test scores,
# - $\mu = 70$,
# - $\sigma = 10$,
# - We want to find the proportion of students scoring **less than** $X = 85$.
#
# **Step A.** Compute the Z-score for $X = 85$:
#
# $$
# Z = \frac{85 - 70}{10} = \frac{15}{10} = 1.5
# $$
#
# **Step B.** Ask: *What is $P(X < 85)$?*
# Because $X < 85 \;\;\Longleftrightarrow\;\; Z < 1.5$.
#
# We can look up $P(Z < 1.5)$ in a standard normal table or use a calculator / programming language (e.g. `scipy.stats.norm.cdf(1.5)`).
#
# That value is about:
#
# $$
# P(Z < 1.5) \approx 0.9332
# $$
#
# So about **93.32%** of students are expected to score less than 85.
#
#
# #### 3. Reverse Lookup: From Proportion to Value
#
# Sometimes we want the opposite: *“What test score corresponds to the 95th percentile?”* In other words:
#
# > Find $x$ such that $P(X < x) = 0.95$.
#
# **Step A.** In standard normal world, find $z$ such that $P(Z < z) = 0.95$.
# From tables or functions, $z \approx 1.645$ (or 1.64 depending on precision).
#
# **Step B.** Turn that back into the original $X$ scale by solving:
#
# $$
# z = \frac{x - \mu}{\sigma}
# \;\;\Longrightarrow\;\;
# x = \mu + z \sigma
# $$
#
# With $\mu = 70, \sigma = 10$:
#
# $$
# x = 70 + (1.645)(10) = 70 + 16.45 = 86.45
# $$
#
# So the 95th percentile score is about **86.45**.
#
#
# #### 4. Why This Matters
#
# - Any normal distribution, no matter its mean or standard deviation, can be converted into the standard normal via standardization.
# - This lets us use one table or one set of tools (cdf, quantile) instead of hav

# %% [markdown]
# ### 🎥 Explore Standardization Further
#
# Want to deepen your understanding of **standardization** and how Z-scores are used to calculate probabilities?
#
# Check out this short video lesson:
#
# 👉 [Watch on YouTube: Standardizing Normal Distributions](https://www.youtube.com/watch?v=2tuBREK_mgE)
#
# The video walks you through:
#
# - Why we standardize normal distributions,
# - How any normal distribution can be converted to the **standard normal** ($\mu = 0$, $\sigma = 1$),
# - Using Z-scores to find proportions (areas under the curve),
# - Doing reverse lookups (from a proportion to a Z-score).
#
# Take notes as you watch, and think about how the examples connect to the practice problems in this notebook!

# %% [markdown]
# ### 🎥 Explore Normalization Further
#
# Want to deepen your understanding of **normalization** and how to **normalize raw data**.
#
# Check out this short video lesson:
#
# 👉 [Watch on YouTube: Min-Max Normalization](https://youtu.be/-LC_PKBoZfk?si=axDsYAqT6fKs-rJ-)
#
# The video walks you through:
#
# - Min-Max Normalization with a numerical example,
# - Normalization with a numerical example,
#
# Take notes as you watch, and think about how the examples connect to the practice problems in this notebook.
#
# We will continue to use normalization during the remainder of the workshop (below)

# %% [markdown]
# ### 📝 In-Class Activity: Stock Market Investment and Z-Scores
#
# You are analyzing the daily returns of a particular stock.
# You know the following information:
#
# - The stock’s mean daily return ($\mu$) is **0.5%**.
# - The daily returns’ standard deviation ($\sigma$) is **2%**.
#
# You want to find out how unusual a **daily return of 5%** is.
#
#
# #### Your Task
#
# 1. **Write down the Z-score formula**:
#
#    $$
#    Z = \frac{X - \mu}{\sigma}
#    $$
#
# 2. **Substitute the values** into the formula using:
#    - $X = 5$ (the daily return in %),
#    - $\mu = 0.5$,
#    - $\sigma = 2$.
#
#    Show your calculation for $Z$.
#
# 3. **Interpret the Z-score**:
#    - What does your calculated Z-score mean in terms of how many standard deviations the 5% return is from the mean?
#    - Is this return unusually high compared to the average?
#
# 4. **Find the probability**:
#    - Use the Z-score you found to determine the cumulative probability $P(X \leq 5)$.
#    - You can use a Z-table or a Python function such as:
#
#      ```python
#      from scipy.stats import norm
#      norm.cdf(Z_value)
#      ```
#
# 5. **Interpret the probability**:
#    - What percentage of daily returns fall below 5%?
#    - What percentage of daily returns exceed 5%?
#
#
# #### 🔎 Reflection Questions
# - Why is a Z-score useful when comparing returns to the average?
# - If the standard deviation were **larger**, how would that affect the Z-score for the same return of 5%?
#
#
# ### 💻 **Now it’s your turn to code!**
# Write a short Python script that:
# - Calculates the Z-score for $X = 5$,
# - Uses `scipy.stats.norm.cdf()` to compute the probability,
# - Prints both results clearly.

# %%
# TODO: Write the code here

# %% [markdown]
# #### 💭 Reflection (In-class Activity): Add Your Talking Point
#
# ---
# TODO: Your reflection goes here
#
#
# ---
#
# <br>
# <br>
# <br>

# %% [markdown]
# ### 📊 Statistical Inference: From Sample to Population
#
# **Statistical inference** is the act of generalizing from a **sample** to a **population** with a calculated degree of certainty.
#
# - We want to learn about **population parameters** …
# - …but we can only calculate **sample statistics**.
#
#
# #### Example: Stock Market Context
#
# - **Population** = Stock Market Performance
# - **Sample (Data)** = Company XYZ Stock
# - **Statistic** = Z-Score (calculated from the sample)
# - **Parameter** = Probability of daily return
#
# We use the **sample statistic** (Z-score from XYZ stock) to make an **inference** about the **population parameter** (probability of daily return across the market).
#
# ![Image Description](./images/InferenceFromSample.png)

# %% [markdown]
# ### 🌍 Challenge #1: Climate Change and Z-Scores
#
# Let’s consider an example where you are analyzing **annual temperature anomalies** to study climate change.
#
# Suppose you have collected data on the annual temperature anomalies (differences from the long-term average temperature) for a particular region over the past 30 years.
#
# - Mean annual temperature anomaly ($\mu$) = **0.5°C**
# - Standard deviation ($\sigma$) = **0.2°C**
#
# You want to understand how unusual a year with a **temperature anomaly of 0.9°C** is.
#
#
# #### 🧩 Your Task
#
# 1. **Use the Z-score formula**:
#
#    $$
#    Z = \frac{X - \mu}{\sigma}
#    $$
#
# 2. **Substitute the values** into the formula using:
#    - $X = 0.9$,
#    - $\mu = 0.5$,
#    - $\sigma = 0.2$.

# %% [markdown]
#    3. 💻 Code the Climate Change Z-Score in Python <br>
#       - Complete the Python code scaffold below.
#       - Calculate the Z-score.
#       - Use `scipy.stats.norm.cdf()` to compute the cumulative probability $P(X \leq 0.9)$.
#       - Interpret the result:
#          - What percentage of years have anomalies less than or equal to 0.9°C?
#          - What percentage have anomalies greater than 0.9°C?
#
# ```python
# from scipy.stats import norm
#
# # Given values
# mu = 0.5   # mean anomaly
# sigma = 0.2  # standard deviation
# X = 0.9   # observed anomaly
#
# # 1. Compute the Z-score
# Z = ( ___ - ___ ) / ___
# print("Z-score:", Z)
#
# # 2. Compute the cumulative probability
# p_less = norm.cdf(___)
# print("P(X <= 0.9):", p_less)
#
# # 3. Compute the probability above 0.9
# p_greater = 1 - p_less
# print("P(X > 0.9):", p_greater)
# ````
#
# <br/>
#
# Write the complete object-oriened Python code the cell below.

# %%
# TODO: Write the code here

# %% [markdown]
# After you have written and tested the code:
#
# 4.  📈 Visualization Exercise: Climate Anomaly Probability **Interpret the Z-score**:
#    - How many standard deviations is 0.9°C above the mean?
#    - Is this anomaly unusually high compared to the average year?
#
#    - Let’s make the result more visual. We’ll plot the normal distribution curve for annual temperature anomalies and shade the probability of having a value **greater than 0.9°C**.
#       - Run the code below.
#       - Observe the shaded region above $X = 0.9$.
#       - Compare the shaded probability with the number you calculated earlier using the Z-score.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Given values
mu = 0.5   # mean anomaly
sigma = 0.2  # standard deviation
X = 0.9   # observed anomaly

# Generate x values for the curve
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
y = norm.pdf(x, mu, sigma)

# Plot the normal distribution curve
plt.plot(x, y, label="Normal Distribution", linewidth=2)

# Shade the region above X = 0.9
x_fill = np.linspace(X, mu + 4*sigma, 500)
y_fill = norm.pdf(x_fill, mu, sigma)
plt.fill_between(x_fill, y_fill, alpha=0.5)

# Add vertical line at X = 0.9
plt.axvline(X, color="red", linestyle="--", label=f"X = {X}")

# Labels and legend
plt.title("Probability of Annual Temperature Anomaly > 0.9°C")
plt.xlabel("Temperature Anomaly (°C)")
plt.ylabel("Density")
plt.legend()
plt.show()

# %% [markdown]
# #### 💭 Reflection (Challenge #1): Add Your Talking Point
#
# ---
# TODO: Your reflection goes here
#
#
# ---
#
# <br>
# <br>
# <br>

# %% [markdown]
# ### 🚀 Challenge #2: Integrating Z-Scores, Visualization, and Web Services
#
# You’ve now completed two separate tasks:
# 1. **Coding the Climate Change Z-Score**: You calculated the Z-score and probabilities using Python code.
# 2. **Visualizing the Climate Anomaly Probability**: You plotted the normal curve and shaded the probability region above $X = 0.9$.
#
# Both tasks are useful on their own, but in real Data Science work we want our tools to be **reusable, organized, and accessible to others**.
#
# ### 🧩 Your Task
#
# Step 1. Combine Both Codes Using Object-Oriented Python
# - Create a Python **class** called `ClimateAnomalyAnalyzer`.
# - The class should:
#   - Store the values of $\mu$, $\sigma$, and $X$ as attributes.
#   - Have a method `compute_zscore()` that calculates and returns the Z-score.
#   - Have a method `compute_probabilities()` that calculates and returns $P(X \leq X)$ and $P(X > X)$.
#   - Have a method `plot_distribution()` that produces the visualization you created earlier (curve + shaded area).
#
#
# Step 2. Build a Flask Web Service
# - Create a **Flask app** that exposes a web service so that users can interact with your analysis.
# - The app should:
#   - Provide a **form** or **query parameters** where the user enters values for $\mu$, $\sigma$, and $X$.
#   - Display the **calculated Z-score** and **probabilities**.
#   - Show the **distribution plot** as an image.
#
# *(Hint: you can save the Matplotlib plot as a `.png` file in memory and serve it in the Flask app.)*
#
#
# Step 3. Test Your Web Service
# Building a web service is only half the job — the other half is **testing it like a user would**. There are three tests for you to implement:
#
# > **Browser Test (quick check):**
#    - Run your Flask app with `python app.py`.
#    - Open a browser and visit:
#      ```
#      http://127.0.0.1:5000/analyze?mu=0.5&sigma=0.2&X=0.9
#      ```
#    - You should see a JSON response or an HTML page with results.
#
# > **Command Line Test with `curl`:**
#    - Run:
#      ```bash
#      curl "http://127.0.0.1:5000/analyze?mu=0.5&sigma=0.2&X=0.9"
#      ```
#    - This checks that the service responds correctly to HTTP requests.
#
# > **Python Test with `requests` library:**
#    ```python
#    import requests
#
#    response = requests.get(
#        "http://127.0.0.1:5000/analyze",
#        params={"mu": 0.5, "sigma": 0.2, "X": 0.9}
#    )
#    print(response.json())

# %%
# TODO: Write the code here

# %% [markdown]
# Step 4. Reflection
#
# Explain how using Object-Oriented Python made your code cleaner and easier to extend.
#
# Reflect on how wrapping your analysis in a Flask web service could make it accessible to others, e.g. policymakers, researchers, or classmates.

# %% [markdown]
# #### 💭 Reflection (Challenge #2): Add Your Talking Point
#
# ---
# TODO: Your reflection goes here
#
#
# ---
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## 📊 T-Score
#
# The **t-score** is a type of standard score used when the **sample size is small** or when the **population standard deviation ($\sigma$) is unknown**.
#
# It works very much like the **z-score**, but with one important difference:
# - Instead of using the population standard deviation ($\sigma$), it uses the **sample standard deviation ($s$)**.
# - It also adjusts for the **sample size ($n$)**, since smaller samples add more uncertainty.
#
#
# ### Formula
#
# $$
# T = \frac{X - \mu}{s / \sqrt{n}}
# $$
#
# Where:
# - $T$ = t-score
# - $X$ = value of the observation
# - $\mu$ = sample mean
# - $s$ = sample standard deviation
# - $n$ = sample size
#
#
# ### Why use the t-score?
# - When $n$ is **large** and $\sigma$ is known → use the **z-score**.
# - When $n$ is **small** or $\sigma$ is unknown → use the **t-score**.
#
# The t-distribution is wider and has heavier tails than the normal distribution, reflecting more uncertainty with smaller samples. As $n$ grows larger, the t-distribution approaches the standard normal distribution.
#
#
# ### 📝 Exercise
#
# You collected the following data on exam scores from a **small sample of $n = 10$ students**:
#
# - Sample mean ($\mu$) = 75
# - Sample standard deviation ($s$) = 8
# - One student scored $X = 90$
#
# **Task:**
# 1. Calculate the t-score for the student’s score of 90.
# 2. Interpret the result: how many standard errors above the sample mean is this student’s score?
# 3. Discuss: why might using the z-score here be misleading?
#
# 💻 *Challenge:* Write Python code using `scipy.stats.t.cdf()` to calculate the probability of observing a score at least this extreme with $n-1$ degrees of freedom.

# %%
# TODO: Write the code here

# %% [markdown]
# ### 🏠 Challenge #3: T-Scores, Housing Prices, and Degrees of Freedom
#
# Let’s revisit the example of house prices in Elmira, Ontario.
# You collected the following sample of house prices (in thousands of dollars) from **10 houses**:
#
# $$
# [450, 470, 430, 490, 410, 460, 440, 480, 500, 455]
# $$
#
# - Sample mean ($\bar{x}$) = 458.5 (thousand dollars)
# - Sample standard deviation ($s$) = 25.21 (thousand dollars)
# - Sample size ($n$) = 10
#
# Suppose you want to determine the **T-score** for a house priced at **500 thousand dollars**.
#
#
# #### 📊 Statistical Background
#
# The **t-distribution** is used when data are approximately normally distributed, but the **population variance is unknown**.
#
# - The variance is estimated using the **degrees of freedom (df)**, defined as:
#
# $$
# df = n - 1
# $$
#
# - Why $n-1$? Because when you calculate a sample mean, one degree of freedom is "used up" — the last value is constrained by the others and the mean.
#
# For this housing dataset:
#
# $$
# df = 10 - 1 = 9
# $$
#
#
# #### 🔢 Formula for the T-Score
#
# The formula is:
#
# $$
# T = \frac{X - \bar{x}}{s / \sqrt{n}}
# $$
#
# Where:
# - $T$ = T-score
# - $X$ = observed value (here, 500)
# - $\bar{x}$ = sample mean (458.5)
# - $s$ = sample standard deviation (25.21)
# - $n$ = sample size (10)
#
#
# #### 📝 Your Task
#
# 1. **Calculate the T-score** for $X = 500$.
# 2. **Interpret the result**: how unusual is this value compared to the sample mean?
# 3. **Use the t-distribution** with $df = 9$ to calculate the probability of observing a value this high or higher.
#    - This is a **one-tailed probability**.
#    - Use Python’s `scipy.stats.t` distribution to do this.
#
#
# #### 💻 Python Scaffold
#
# Here’s some starter code to guide you:
#
# ```python
# import numpy as np
# from scipy.stats import t
#
# # Given values
# x_bar = 458.5
# s = 25.21
# n = 10
# X = 500
#
# # 1. Compute the T-score
# T = ( ___ - ___ ) / ( ___ / np.sqrt(n) )
# print("T-score:", T)
#
# # 2. Degrees of freedom
# df = n - 1
# print("Degrees of freedom:", df)
#
# # 3. Compute one-tailed probability P(T >= observed)
# p_value = 1 - t.cdf(T, df)
# print("P-value (one-tailed):", p_value)
#
#
#
# Write the code on the cell below. Don't forget to make it **Object Oriented Python**

# %%
# TODO: Write the code here

# %% [markdown]
# #### 💭 Reflection (Challenge #3): Add Your Talking Point
#
# ---
# TODO: Your reflection goes here
#
#
# ---
#
# <br>
# <br>
# <br>

# %% [markdown]
# # 📈 Test for Normality
#
# Before applying many statistical methods, we need to check whether the data follow a **normal distribution**.
#
# A **normality test** helps us decide if it is reasonable to assume the data are normally distributed.
#
# **Why Normalize a dataset?**
# In Machine Learning, features can have very different scales (e.g., age in years vs. income in dollars).
# If left unnormalized, algorithms that rely on distance (like K-Nearest Neighbors, k-Means, or gradient descent in neural networks) can become biased toward features with larger values.
#
# 👉 Normalization rescales all features to the same range (commonly 0 to 1), ensuring that **each feature contributes fairly** to the model.
#
# <br/>
#
# ### 🔑 Assumptions: Data Independence
#
# When performing a test for normality, we assume that the data are **independent**.
# This means:
#
# 1. **Independent Collection:**
#    - Example: Water hardness data samples across the UK were collected by **source A**.
#    - Mortality rates across the UK were collected by **source B**.
#
# 2. **No Pairing or Matching:**
#    - The two samples (water hardness and mortality rates) are not paired or matched.
#
# 3. **No Dependence:**
#    - The two sets of measurements do not depend on each other.
#
#
# ### 🗂️ Example Dataset
#
# We are working with the following dataset (from `water.csv`):
#
# | location | town        | mortality | hardness |
# |----------|-------------|-----------|----------|
# | South    | Bath        | 1247      | 10

# %% [markdown]
# ### Import the data set.
#
# #### Reading and Exporting Water Data from HSAUR Package in R
#
# The `water` dataset is originally available in the `HSAUR` package in R. To use this dataset in a Jupyter Notebook, we first need to read it into the R programming environment and then export it to a CSV file. Here are the steps involved:
#
# 1. **Install and Load the HSAUR Package**:
#    - If the `HSAUR` package is not already installed, we need to install it using `install.packages("HSAUR")`.
#    - Load the package using `library(HSAUR)`.
#
# 2. **Read the Water Data**:
#    - The `water` dataset can be accessed directly from the `HSAUR` package using the command `data("water")`.
#
# 3. **Export the Data to a CSV File**:
#    - Once the data is loaded into the R environment, we can use the `write.csv()` function to export it to a CSV file. For example, `write.csv(water, "water.csv")` will save the dataset as `water.csv` in the current working directory.
#
# Below is the R code that performs these steps. We already executed it for you and stored the CSV file in the 'data' sub-folder.
#
# ```r
# # Install and load the HSAUR package
# if(!require(HSAUR)){install.packages("HSAUR")}
# library(HSAUR)
#
# # Load the water dataset
# data("water")
#
# # Export the dataset to a CSV file
# write.csv(water, "water.csv")

# %% [markdown]
# #### Import all necessary libraries

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.preprocessing import MinMaxScaler

# %%
# Read in Water Data
water = pd.read_csv(".\data\water.csv")
water.head()

# %% [markdown]
# #### Display Summary Statistics on the data we just imported.

# %%
# Summary statistics
desc_water = water.iloc[:, 2:4].describe()
desc_water.round(2)

# Additional summary
water.describe()

# %% [markdown]
# #### Graphical Summary of the data on water, mortality and hardness.

# %%
# Histograms and density plots
sns.histplot(water['mortality'], bins=12, kde=True)
plt.xlabel('Mortality')
plt.title('Distribution of Mortality')
plt.show()

sns.histplot(water['hardness'], bins=12, kde=True)
plt.xlabel('Hardness')
plt.title('Distribution of Water Hardness')
plt.show()

# %% [markdown]
# ### 📉 Are these normal curves? Not really...
#
# <br/>

# %% [markdown]
# #### 🔑 Why Normalize the Data?
#
# You have two features in the `water.csv` dataset:
#
# * **Mortality** (ranges around 1200–2000)
# * **Hardness** (ranges around 5–120)
#
# These features are on **very different scales**.
# If you use them directly in **distance-based models** (like K-Nearest Neighbors) or **gradient descent–based models** (like Logistic Regression, Neural Networks), the larger-scaled feature (**Mortality**) will dominate.
#
# 👉 This means the model may **ignore water hardness** just because mortality values are numerically larger.
#
# **Normalization** rescales the features so they’re comparable, ensuring **each feature contributes fairly** to the model.
#
# #### 🧪 Demonstration in Python
#
# We’ll prove this using **K-Nearest Neighbors (KNN)**, a distance-based classifier.
# I’ll create a simple experiment: predict whether a town is in the **North or South** based on `mortality` and `hardness`.
#
# #### 1. Without Normalization

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# Features and labels
X = water[['mortality', 'hardness']]
y = water['location']

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

# KNN without normalization
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print("Accuracy WITHOUT normalization:", accuracy_score(y_test, y_pred))

# %% [markdown]
# #### 2. With Normalization (Min-Max Scaling)

# %%
# Normalize features to [0,1] range
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Train/test split again (on scaled features)
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X_scaled, y, random_state=42, test_size=0.3)

# KNN with normalization
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_s, y_train_s)
y_pred_s = knn.predict(X_test_s)

print("Accuracy WITH normalization:", accuracy_score(y_test_s, y_pred_s))

# %% [markdown]
# #### 🎯 What to Observe
#
# * The **accuracy without normalization** may be poor because the large scale of `mortality` overwhelms `hardness`.
# * After **normalization**, `hardness` is on equal footing with `mortality`, so the classifier can use **both features effectively**.
#
# 💡 **Takeaway:**
# Always check the **scale of your features**. If they differ significantly, normalize (or standardize) before running experiments. Otherwise, you risk biased models.

# %% [markdown]
# ### 🧪 Shapiro-Wilk Test: Beyond Visual Inspection
#
# When we look at histograms or density plots, we can often *guess* whether the data look approximately normal.
# But in **machine learning workflows**, relying on **visual inspection** is not practical:
#
# - It is subjective — two people may interpret the same plot differently.
# - It doesn’t scale — imagine inspecting thousands of features across hundreds of datasets.
#
#
# #### 🔑 Enter the Shapiro-Wilk Test
# The **Shapiro-Wilk test** provides a **formal statistical test for normality**.
#
# - **Null hypothesis ($H_0$):** The data come from a normal distribution.
# - **Alternative hypothesis ($H_1$):** The data do not come from a normal distribution.
#
# It produces a **p-value**:
# - If `p > 0.05`: fail to reject $H_0$ → data are likely normal.
# - If `p <= 0.05`: reject $H_0$ → data is **unlikely** to be normal.
#
# Since the p-value is smaller than the commonly used **significance level** of $\alpha = 0.05$, we reject the null hypothesis $H_0$.

# %% [markdown]
# #### 🧠 Reflection Activity: Understanding the p-value
#
# **What is a p-value anyway?**
#
# 👉 A p-value tells us how surprising our data would be if nothing unusual was going on (i.e., if the null hypothesis were true).
#
# - A **small p-value** ($p \leq \alpha$) means:
#   “Wow, this result would be very unlikely if nothing unusual was happening.”
#    <br/>or more specifically:<br/>
#   "Wow, this data would be very unlikely if it were truly normal."
#
# - A **large p-value** ($p > \alpha$) means:
#   “This result isn’t surprising at all; it could easily happen just by chance.”
#    <br/>or more specifically:<br/>
#   "This data isn’t surprising at all; it could easily come from a normal distribution."
#
# #### 🤔 Not sure what this means?
#
# Try this guided conversation with your LLM (Language Learning Model):
#
# 1. Ask:
#    > You are a seasoned Data Scientist. Would you agree with this statement:
#    > “Wow, this result would be very unlikely if nothing unusual was happening.”?
#
# 2. Then ask:
#    > Now give me a use case with an example distribution that matches the argument.
#
# 3. Finally ask:
#    > In that case, fill in the blank:
#    > “Wow, this result would be very unlikely if nothing unusual was happening with ________________________.”
#
# #### ✍️ Your Turn
#
# Now reflect on your conversation with the LLM and write your own null and alternative hypotheses below:
#
# **Null Hypothesis ($H_0$):**
# 💭 *Write your statement in the cell below.*

# %% [markdown]
# ---
# TODO: Your statement goes here
#
#
# ---

# %% [markdown]
# **Alternative Hypothesis ($H_1$):**
# 💭 *Write your statement in the cell below.*

# %% [markdown]
# ---
# TODO: Your statement goes here
#
#
# ---
#
# <br>

# %% [markdown]
# #### 🧠 Reflection Activity: More ways to understand the p-value

# %% [markdown]
# 👉 A p-value is like asking: “If the world was completely normal and nothing special was happening, how often would I expect to see results like this just by chance?”
#
# - If the p-value is small, it means: “This result almost never happens just by chance — maybe something real is going on.”
# - If the p-value is large, it means: “This result is common enough that it could easily happen by chance — nothing special to see here.”

# %% [markdown]
# 👉 Imagine you flip a fair coin. Normally, you’d expect about half heads and half tails.
#
# Now suppose you flip it 10 times and get 10 heads in a row.
# The p-value answers the question:
#
# “If this coin were truly fair, how likely would it be to see 10 heads in a row?”
#
# - If that probability (the p-value) is very small, you start to suspect the coin isn’t fair.
# - If it’s not that small, then the result could just be normal chance.

# %% [markdown]
# 👉 A p-value is just a number that tells you how much your result looks like it could be a random accident.
#
# - A small p-value means: “This doesn’t look like an accident — something real might be happening.”
# - A big p-value means: “This looks like it could easily be an accident — probably nothing unusual here.”

# %% [markdown]
# ### 🎲 Understanding the p-value
#
# 👉 **What is a p-value?**
#
# 1. **Simplest view:**
#    A p-value is a number that tells you how much your result looks like it could be a **random accident**.
#    - Small p-value → unlikely to be an accident.
#    - Large p-value → could easily be an accident.
#
# 2. **Everyday analogy (coin flips):**
#    Imagine flipping a fair coin. If you get **10 heads in a row**, the p-value answers:
#    *“If the coin were really fair, how likely would it be to see this result?”*
#
# 3. **Plain English version:**
#    The p-value is the chance of seeing results **at least as extreme as yours** if nothing unusual is happening.
#
# 4. **Statistical phrasing (when we can’t avoid it):**
#    The p-value is the probability of observing your data, or something more extreme, **assuming the null hypothesis is true**.
#
# 💡 **Takeaway:**
# The smaller the p-value, the stronger the evidence that your result is *not* just random chance.

# %% [markdown]
# ### 🔗 Connecting p-values and the Shapiro-Wilk Test
#
# The **Shapiro-Wilk test** is a statistical test for checking whether a dataset is normally distributed.
# It produces a **p-value**, which we interpret just like any other p-value:
#
# - **Null hypothesis ($H_0$):** The data come from a normal distribution.
# - **Alternative hypothesis ($H_1$):** The data do not come from a normal distribution.
#
# 👉 The p-value tells us how much the data could look like a **random accident** under the assumption of normality.
#
# - If **p > 0.05** → the data do not provide strong evidence against $H_0$, so it is reasonable to assume the data are normal.
# - If **p ≤ 0.05** → the data are unlikely under $H_0$, so we conclude the data are not normally distributed.
#
# 💡 In short: the **Shapiro-Wilk test uses the p-value to automate the decision** of whether a dataset is “normal enough” to justify using methods that assume normality.

# %%
# Shapiro-Wilk test for normality
shapiro_hardness = stats.shapiro(water['hardness'])
shapiro_mortality = stats.shapiro(water['mortality'])
print(f"Shapiro-Wilk test for hardness: {shapiro_hardness}")
print(f"Shapiro-Wilk test for mortality: {shapiro_mortality}")

# Q-Q plots
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Q-Q plot for hardness
stats.probplot(water['hardness'], dist="norm", plot=axes[0])
axes[0].set_title('Q-Q Plot for Hardness')

# Q-Q plot for mortality
stats.probplot(water['mortality'], dist="norm", plot=axes[1])
axes[1].set_title('Q-Q Plot for Mortality')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### ⚙️ Why It Matters in ML Operations
# - In automated ML pipelines, we cannot visually inspect every feature.
# - Tests like **Shapiro-Wilk** give us a **systematic, programmatic way** to decide whether normality assumptions hold.
# - This helps us choose the right tools:
#   - If normal → use **parametric methods** (e.g., linear regression, t-tests).
#   - If not normal → consider **non-parametric methods** (e.g., Mann-Whitney test, tree-based models).
#
#
# 👉 In short: **visual inspection is good for learning**, but **automated testing is essential for scaling machine learning operations.**

# %% [markdown]
# #### Comparing Mortality and Hardness by Location

# %%
# Box plots
sns.boxplot(x='location', y='hardness', data=water)
plt.title('Hardness by Location')
plt.xlabel('Regions')
plt.show()

sns.boxplot(x='location', y='mortality', data=water)
plt.title('Mortality by Location')
plt.xlabel('Regions')
plt.show()

# %% [markdown]
# ### 🎥 Explore p-values Further
#
# Want to deepen your understanding of **p-values** and how to **Statistical Hypothesis Tests** ?.
#
# Check out this short video lesson:
#
# 👉 [Watch on YouTube: What is a p-value?](https://youtu.be/ukcFrzt6cHk?si=tHVMt9vXkvXMWTX3)
#
# The video walks you through:
#
# - The formal definition of p-value in the context of observations,
# - The formal definition of p-value in the context of probabilty,
# - It's use in a drug administration use case,
# - The concept of **Random Noise**,
#
# Take notes as you watch, and think about how the examples connect to the practice problems in this notebook.

# %% [markdown]
# ### 🌍 Challenge #5 : Country Data — Normality & Normalization
#
# Use two free APIs about **country statistics / demographics** to fetch data, test for normality, normalize/standardize, visualize, and reflect.
#
# #### 📡 Suggested APIs to Use
# Here are two APIs that give country-level data, with numeric fields, and are free or have free endpoints:
#
# 1. **REST Countries API** — [https://restcountries.com/](https://restcountries.com/)
#    - Returns data on countries: population, area, region, etc. :contentReference[oaicite:0]{index=0}
#    - No API key needed.
#
# 2. **World Bank API** — [https://api.worldbank.org/v2/country](https://api.worldbank.org/v2/country)
#    - Provides country metadata plus statistical indicators if extended, or for starters population / income etc. :contentReference[oaicite:1]{index=1}
#    - Free to use.
#
# #### 💡 Tasks
#
# 1. **Fetch data** from both APIs:
#    - For each API, get at least **100 countries**, and pick **two or more numeric features** (e.g. population, area, GDP per capita, life expectancy).
#    - Load into DataFrames.
#
# 2. **Check for normality** using the **Shapiro-Wilk test** on each numeric feature:
#    - Compute p-values.
#    - Note which features are *not* normal (p ≤ 0.05).
#
# 3. **Transform (if needed)** those “not normal” features:
#    - Normalize via Min-Max scaling (to range 0-1).
#    - Standardize (z-score: mean = 0, standard deviation = 1).
#
# 4. **Visualize before & after transformations**:
#    - Use **box plots** for each feature before transformation.
#    - Box plots after normalization.
#    - Box plots after standardization.
#    - Display side by side for comparison.
#
# 5. **Reflection / Talking Points**: Write at least three short points about:
#    - Why normalization/standardization was needed (or not) in your datasets.
#    - How differences in scale showed up (outliers, spread).
#    - Implications for using these datasets in ML models (distance-based, etc.).
#
# #### 🐍 Python Scaffold
#
# ```python
# import requests
# import pandas as pd
# from scipy.stats import shapiro
# from sklearn.preprocessing import MinMaxScaler, StandardScaler
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# def test_normality(df, cols):
#     results = {}
#     for c in cols:
#         vals = df[c].dropna()
#         if len(vals) >= 3:
#             stat, p = shapiro(vals)
#             results[c] = p
#     return results
#
# # API 1: REST Countries
# url1 = "https://restcountries.com/v3.1/all"
# resp1 = requests.get(url1)
# data1 = pd.json_normalize(resp1.json())
# # Example numeric features
# num_cols1 = ['population', 'area']
#
# # API 2: World Bank — get country data
# url2 = "https://api.worldbank.org/v2/country?format=json&per_page=300"
# resp2 = requests.get(url2)
# # World Bank returns a list of two elements: metadata and actual data
# wb_data = resp2.json()[1]
# data2 = pd.DataFrame(wb_data)
# # Example numeric features (you might need to filter or convert)
# num_cols2 = ['population', 'longitude', 'latitude']  # or other numeric fields available
#
# # 1. Normality before transformations
# pvals1_before = test_normality(data1, num_cols1)
# pvals2_before = test_normality(data2, num_cols2)
# print("P-values before:", pvals1_before, pvals2_before)
#
# # 2. Normalize / Standardize
# minmax = MinMaxScaler()
# stdscaler = StandardScaler()
#
# data1_norm = data1.copy()
# data1_norm[num_cols1] = minmax.fit_transform(data1[num_cols1])
#
# data1_std = data1.copy()
# data1_std[num_cols1] = stdscaler.fit_transform(data1[num_cols1])
#
# # 3. Normality after transformations
# pvals1_norm = test_normality(data1_norm, num_cols1)
# pvals1_std = test_normality(data1_std, num_cols1)
# print("P-values after Min-Max (REST Countries):", pvals1_norm)
# print("P-values after Standardization (REST Countries):", pvals1_std)
#
# # 4. Visualization
# fig, axes = plt.subplots(3, len(num_cols1), figsize=(6 * len(num_cols1), 12))
# for i, c in enumerate(num_cols1):
#     sns.boxplot(y=data1[c], ax=axes[0, i])
#     axes[0, i].set_title(f"{c} before")
#     sns.boxplot(y=data1_norm[c], ax=axes[1, i])
#     axes[1, i].set_title(f"{c} normalized")
#     sns.boxplot(y=data1_std[c], ax=axes[2, i])
#     axes[2, i].set_title(f"{c} standardized")
# plt.tight_layout()
# plt.show()
#
#
# Write the code on the cell below. Don't forget to make it **Object Oriented Python**

# %%
# TODO: Write the code here

# %% [markdown]
# #### 💭 Reflection (Challenge #5): Add Your Talking Point
#
# ---
# TODO: Your reflection goes here
#
#
# ---
#
# <br>
# <br>
# <br>

# %% [markdown]
# # 📈 Normalization, part 2
#
# ### Most of the time, our raw data will not be normalized.
#
# Min-max normalization scales data to a fixed range, typically [0, 1], ensuring that no single feature dominates due to its scale. This is crucial when features have different units or ranges, as it prevents biased model performance. It also improves the efficiency of gradient-based optimization algorithms, leading to faster and more stable convergence. Additionally, normalization enhances data visualization, making it easier to compare and interpret relationships between features. Overall, min-max normalization is essential for improving the performance, efficiency, and interpretability of data analysis and machine learning models.

# %% [markdown]
# ### Step 1 - graph the raw data (not normalized)

# %%
# Graph the unscaled data
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.histplot(water['mortality'], bins=16, kde=True, ax=axes[0])
axes[0].set_title('Distribution of Mortality (Unscaled)')
axes[0].set_xlabel('Mortality')

sns.histplot(water['hardness'], bins=16, kde=True, ax=axes[1])
axes[1].set_title('Distribution of Hardness (Unscaled)')
axes[1].set_xlabel('Hardness')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 2 - Apply the Min-Max scaler

# %%
# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Select the columns to normalize
columns_to_normalize = ['mortality', 'hardness']

# Apply the scaler to the selected columns
water[columns_to_normalize] = scaler.fit_transform(water[columns_to_normalize])

# Display the first few rows of the normalized dataset
water.head()

# %% [markdown]
# ## Step 3 - Graph the normalized data

# %%
# Graph the scaled data
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.histplot(water['mortality'], bins=16, kde=True, ax=axes[0])
axes[0].set_title('Distribution of Mortality (Scaled)')
axes[0].set_xlabel('Mortality')

sns.histplot(water['hardness'], bins=16, kde=True, ax=axes[1])
axes[1].set_title('Distribution of Hardness (Scaled)')
axes[1].set_xlabel('Hardness')

plt.tight_layout()
plt.show()

# %% [markdown]
# # ✅ Checkpoint
# # 📊 Data Analysis Tasks from the Intro to Inference Workshop
#
# Now that you have completed the workshop so far, you should be able to perform the following data analysis tasks, and more importantly, understand **why each step matters**.
#
# Here is a list of the key topics and their respective **talking points**.
#
# ## 1. Exploratory Data Analysis (EDA)
# - Load datasets into Pandas DataFrames
# - Summarize data with descriptive statistics (mean, median, std, etc.)
# - Visualize distributions using histograms, density plots, and box plots
# 🔑 **Why?** EDA provides the first look at the structure of the data and helps identify patterns, outliers, or errors before deeper analysis.
#
# ---
#
# ## 2. Z-Score Applications
# - Compute Z-scores for individual data points
# - Interpret Z-scores as “how many standard deviations away from the mean”
# - Calculate probabilities using the standard normal distribution
# - Perform reverse lookups (percentile → value)
# 🔑 **Why?** Z-scores make different datasets comparable and allow probability-based reasoning on any normally distributed variable.
#
# ---
#
# ## 3. T-Score and Degrees of Freedom
# - Understand when to use t-scores instead of z-scores
# - Calculate t-scores with small samples and unknown population variance
# - Interpret results using degrees of freedom ($df = n-1$)
# - Apply one-tailed and two-tailed reasoning
# 🔑 **Why?** T-scores extend inference to small samples, where population parameters are unknown, making analysis more realistic for limited datasets.
#
# ---
#
# ## 4. Normality Testing
# - Use visual inspection (histograms, KDE plots) to check for normality
# - Apply the **Shapiro-Wilk test** to formally test normality
# - Interpret p-values to decide if data are “normal enough”
# 🔑 **Why?** Many statistical tests assume normality; testing ensures we use the right methods (parametric vs non-parametric).
#
# ---
#
# ## 5. P-Value Interpretation
# - Understand p-values as a measure of how much results could be due to chance
# - Apply p-values in the context of hypothesis testing
# - Connect p-values to decisions (reject / fail to reject the null hypothesis)
# 🔑 **Why?** P-values provide an objective way to decide whether an observed effect is likely real or just random variation.
#
# ---
#
# ## 6. Normalization and Standardization
# - Normalize data using **Min-Max scaling** (rescaling to [0, 1])
# - Standardize data using **z-score scaling** (mean = 0, std = 1)
# - Understand why normalization is important for ML models (e.g., KNN, clustering)
# - Compare before-and-after transformations with visualizations
# 🔑 **Why?** Rescaling prevents features with large ranges from overpowering others, ensuring fair contributions in machine learning algorithms.
#
# ---
#
# ## 7. Visualization for Inference
# - Create and interpret histograms, density plots, and box plots
# - Visualize probability areas under curves (shaded plots)
# - Compare raw vs. normalized vs. standardized data side by side
# 🔑 **Why?** Visuals make abstract statistical concepts intuitive and reveal insights that numbers alone may hide.
#
# ---
#
# ## 8. Applied Challenges
# - Analyze real-world datasets (e.g., climate anomalies, housing prices, water hardness)
# - Fetch data from APIs, flatten JSON into DataFrames, and clean numeric features
# - Test real-world data for normality and prepare it for ML workflows
# 🔑 **Why?** Applying theory to real datasets builds confidence and shows how statistical methods support practical decision-making.
#
# ---
#
# ## 9. Critical Reflection
# - Write short reflections/talking points on why statistical preprocessing matters
# - Explain, in plain language, why results can or cannot be trusted
# - Connect statistical analysis to responsible, evidence-based decision making
# 🔑 **Why?** Reflection deepens understanding and helps bridge the gap between technical results and clear communication with stakeholders.

# %% [markdown]
# # 🔄 Data Analysis Workflow: Apply These 9 Steps to Every Project
#
# Follow this workflow every time you start a new project.
# It will guide you even when the data feels incomplete, inaccurate, imprecise, or missing.
#
# ## 🌟 The Workflow
#
# ➡️ **Step 1: EDA**
# 📊 Explore → summarize → visualize → spot gaps.
#
# ➡️ **Step 2: Z-Scores**
# 📐 Standardize to compare across scales.
#
# ➡️ **Step 3: T-Scores**
# 🧮 Small samples? Unknown variance? Use t-distribution.
#
# ➡️ **Step 4: Normality Testing**
# 🔔 Check assumptions → decide on parametric vs non-parametric.
#
# ➡️ **Step 5: P-Values**
# 🎲 Quantify how likely results are due to chance.
#
# ➡️ **Step 6: Normalize & Standardize**
# ⚖️ Put features on fair scales for ML models.
#
# ➡️ **Step 7: Visualization**
# 👀 Show what numbers hide.
#
# ➡️ **Step 8: Applied Challenges**
# 🌍 Test theory on real-world messy data.
#
# ➡️ **Step 9: Reflection**
# 💭 Pause → ask: “What do these results *really* mean?”
#
# ---
#
# ## 🚧 When Data Is Messy or Incomplete
#
# ❓ **Step A: Assess Data Quality**
# - Identify missing, inaccurate, or imprecise values.
#
# 🛠️ **Step B: Impute or Transform**
# - Fill gaps (mean, median, model-based) or flag as unknown.
#
# 🔍 **Step C: Sensitivity Analysis**
# - Ask: *“If the missing data were different, would my conclusions change?”*
#
# 📑 **Step D: Document Assumptions**
# - Be transparent: write down what was missing and how you handled it.
#
# ---

# %% [markdown]
# ![Image Description](./images/DataAnalysisWorkflow.png)

# %% [markdown]
# ## 🔁 Key Takeaway
#
# ✨ Apply this workflow **every project, every dataset**.
# Challenges are not roadblocks — they are **opportunities to show rigor, resilience, and critical thinking**.

# %% [markdown]
# ## 🔬 Expanding Beyond the Workflow
#
# You have now completed the **9-step workflow**, learning how to explore, test, transform, and reflect on data. The next step in your Data Science journey is deciding **which statistical test to use** when working with real-world datasets. This is where statistical inference becomes truly powerful.
#
# Different questions call for different tools. For example:
# - Do two groups differ from each other?
# - Is there a relationship between two variables?
# - Does one factor explain variation in another?
# - Can we predict outcomes with some confidence?
#
# Statistical tests give us structured ways to answer these questions, but choosing the right test depends on the **type of data** (numeric vs. categorical), the **assumptions** (normality, equal variances), and the **goal of analysis** (comparison, association, prediction).
#
# To guide you, here is a great visual overview of **must-have basics** for selecting statistical tests:
#
# 🔗 [Must-Have Basics of Statistical Tests](https://www.linkedin.com/posts/milan-janosov_a-great-overview-of-the-must-have-basics-activity-7313828947098525699-3lu5?utm_source=share&utm_medium=member_desktop&rcm=ACoAAABDyisByD1UhiTq0CzUsB4BQ6v6Y8rgjQ0)
#
# ![Image Description](./images/StatisticalTestsYouNeedToKnowAbout.jpg)
# ---
#
# ## 🧩 Mapping to Our Workshop Datasets
#
# - **Water hardness vs. mortality** → correlation / regression tests
# - **Housing prices (Elmira example)** → one-sample or two-sample t-tests
# - **Climate anomalies** → z-tests or probability intervals
# - **API datasets (countries, NHL stats)** → chi-square tests (categorical) or ANOVA (comparing groups)
#
# 👉 In the next section, you will practice selecting and applying these tests, linking real-world data to the appropriate statistical framework.

# %% [markdown]
# ---

# %% [markdown]
# ## 🧮 Understanding the T-Test
#
# The **T-Test** is a statistical test used to determine whether the means of **two groups** are significantly different from each other.
# It is often applied when we have small sample sizes and we don’t know the population variance.
#
# In practice, a t-test helps answer questions like:
# - *“Do two groups of students score differently on the same exam?”*
# - *“Is there a meaningful difference between two treatment groups in an experiment?”*
#
# ### 🔑 Assumptions of the T-Test
#
# For the t-test results to be valid, the following assumptions should hold:
#
# 1. **Independence** → The two data sets (samples) are independent of each other.
# 2. **Normality** → Each data set is approximately normally distributed.
# 3. **Equal Variance (Homogeneity of Variance)** → Both groups have similar variance.
# 4. **Equal Sample Size** → Both groups have the same number of samples.
# 5. **Low Cardinality** → Works best with relatively small sample sizes (around 20–30, not much larger).
#
# ### 🧩 Why It Matters
#
# If these assumptions are satisfied, the t-test gives a reliable way to check if an observed difference between two sample means is likely due to chance — or if it reflects a **real underlying difference** between the groups.

# %% [markdown]
# ### 🧪 T-Test in Python
#
# We can run a **two-sample t-test** in Python using `scipy.stats.ttest_ind()`.
# This function checks whether the means of two independent samples are significantly different.
#
# ### 💻 Python Scaffold
#
# ```python
# import pandas as pd
# from scipy.stats import ttest_ind
#
# # Load dataset
# water = pd.read_csv("./data/water.csv")
#
# # Example: Compare mortality between two groups of towns
# # Split into two samples (e.g., low hardness vs. high hardness)
# group_low = water[water['hardness'] < water['hardness'].median()]['mortality']
# group_high = water[water['hardness'] >= water['hardness'].median()]['mortality']
#
# # Run independent two-sample t-test
# t_stat, p_val = ttest_ind(group_low, group_high, equal_var=True)
#
# print("T-statistic:", t_stat)
# print("p-value:", p_val)
#
# # Interpretation
# if p_val < 0.05:
#     print("Result: Significant difference between the two groups (reject H0).")
# else:
#     print("Result: No significant difference (fail to reject H0).")

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

# Step 1: Load the dataset from CSV
# Assumes the file is located at ./data/water.csv and contains columns: location, town, mortality, hardness
water = pd.read_csv("./data/water.csv")

# Step 2: Define two groups based on water hardness
# We use the median hardness value to split towns into 'low hardness' and 'high hardness' groups
median_hardness = water['hardness'].median()
group_low = water[water['hardness'] < median_hardness]['mortality']
group_high = water[water['hardness'] >= median_hardness]['mortality']

# Step 3: Perform an independent two-sample t-test
# This tests whether the mean mortality differs significantly between the two hardness groups
# equal_var=True assumes both groups have equal variance (can be changed to False for Welch's test)
# ttest_ind()
t_stat, p_val = ttest_ind(group_low, group_high, equal_var=True)

# Step 4: Print the test statistics
print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_val:.4f}")

# Step 5: Interpret the result
# If p-value < 0.05, we reject the null hypothesis and conclude a significant difference
if p_val < 0.05:
    print("Result: Significant difference between the two groups (reject H₀).")
else:
    print("Result: No significant difference (fail to reject H₀).")

# %% [markdown]
# ### 🏆 Challenge #6: Applying the T-Test to Real Data
#
# You’ve learned how the **t-test** works and practiced with a scaffold. Now it’s time to apply your skills to a real dataset and interpret the results.
#
# ### 🎯 Your Task
#
# Use the `water.csv` dataset to test whether **water hardness levels** have a significant effect on **mortality** rates.
#
# Implement the code in the scaffolding provided earlier.
#
#
# ### 🔑 Steps to Complete
#
# 1. **Load the dataset** (`water.csv`) and explore the columns.
#    - Inspect summary statistics and visualize distributions for `mortality` and `hardness`.
#
# 2. **Create two groups** based on water hardness:
#    - Group 1: Towns with **low hardness** (below the median)
#    - Group 2: Towns with **high hardness** (above or equal to the median)
#
# 3. **Check assumptions** for the t-test:
#    - Use the **Shapiro-Wilk test** (`scipy.stats.shapiro`) to check for normality.
#
# 4. **Run a two-sample t-test** (`scipy.stats.ttest_ind`) on mortality between the two groups.
#
# 5. **Interpret the results**:
#    - Report the t-statistic and p-value.
#    - Decide whether to reject or fail to reject the null hypothesis ($H_0$: no difference in mortality).
#    - Explain what this means in the context of water hardness and mortality.
#
# 6. **Stretch Goal (optional)**
#    - Instead of splitting at the median, try splitting into **quartiles** (lowest 25% vs highest 25%).
#    - Compare results: does the conclusion change when the groups are more extreme?
#
# ---
#
# ## 💡 Reflection
#
# Write 3–4 sentences to answer as talking points:
# - Did the data satisfy the t-test assumptions?
# - Was there a statistically significant difference in mortality between groups?
# - What does this tell you about the relationship between water hardness and mortality?

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind, shapiro

# Step 1: Load dataset
water = pd.read_csv("./data/water.csv")

# Step 2: Summary statistics
summary = water.describe()
print(summary)

# Step 3: Save distribution plots
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(water['mortality'], bins=10, color='skyblue', edgecolor='black')
plt.title('Mortality Distribution')
plt.xlabel('Mortality')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(water['hardness'], bins=10, color='salmon', edgecolor='black')
plt.title('Hardness Distribution')
plt.xlabel('Hardness')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()


# Step 4: Split into two groups by median hardness
median_hardness = water['hardness'].median()
group_low = water[water['hardness'] < median_hardness]['mortality']
group_high = water[water['hardness'] >= median_hardness]['mortality']

# Step 5: Normality check using Shapiro-Wilk test

shapiro_low = shapiro(group_low)
shapiro_high = shapiro(group_high)

print(f"Low Hardness: shapiro W={shapiro_low.statistic:.3f}, p={shapiro_low.pvalue:.4f}")
print(f"High Hardness: shapiro W={shapiro_high.statistic:.3f}, p={shapiro_high.pvalue:.4f}")

# Step 6: T-test
# t_stat, p_val = ttest_ind(group_low, group_high, equal_var=False)
t_stat, p_val = ttest_ind(group_low, group_high)
print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_val:.4f}")

if p_val < 0.05:
    print("Result: Significant difference in mortality between low and high hardness groups (reject H₀).")
else:
    print("Result: No significant difference in mortality (fail to reject H₀).")

# Step 7: Save boxplot
plt.figure(figsize=(6, 4))
# plt.boxplot([group_low, group_high], labels=['Low Hardness', 'High Hardness'])
plt.boxplot([group_low, group_high], tick_labels=['Low Hardness', 'High Hardness'])
plt.title('Mortality by Water Hardness Group')
plt.ylabel('Mortality')
plt.grid(True)
plt.show()



# Define quartiles
q1 = water['hardness'].quantile(0.25)
q3 = water['hardness'].quantile(0.75)

group_q1 = water[water['hardness'] <= q1]['mortality']
group_q3 = water[water['hardness'] >= q3]['mortality']

# Shapiro-Wilk for quartile groups
print("Quartile Normality Checks:")
print("Q1:", shapiro(group_q1))
print("Q3:", shapiro(group_q3))

# T-test for quartile groups
t_q, p_q = ttest_ind(group_q1, group_q3, equal_var=False)
print(f"Quartile T-statistic: {t_q:.3f}")
print(f"Quartile P-value: {p_q:.4f}")

if p_q < 0.05:
    print("Result: Significant difference in mortality between extreme hardness quartiles (reject H₀).")
else:
    print("Result: No significant difference in mortality between quartiles (fail to reject H₀).")
# Out:
#          mortality    hardness
# count    61.000000   61.000000
# mean   1524.147541   47.180328
# std     187.668754   38.093966
# min    1096.000000    5.000000
# 25%    1379.000000   14.000000
# 50%    1555.000000   39.000000
# 75%    1668.000000   75.000000
# max    1987.000000  138.000000
# Low Hardness: shapiro W=0.991, p=0.9963
# High Hardness: shapiro W=0.957, p=0.2468
# T-statistic: 4.390
# P-value: 0.0000
# Result: Significant difference in mortality between low and high hardness groups (reject H₀).
# Quartile Normality Checks:
# Q1: ShapiroResult(statistic=np.float64(0.9580411656285839), pvalue=np.float64(0.5642972458773923))
# Q3: ShapiroResult(statistic=np.float64(0.9624938853041455), pvalue=np.float64(0.7071994597909579))
# Quartile T-statistic: 6.219
# Quartile P-value: 0.0000
# Result: Significant difference in mortality between extreme hardness quartiles (reject H₀).

# %% [markdown]
# ### 💡 Reflection: T-Test Analysis
#
# - The Shapiro-Wilk test confirmed that both low and high hardness groups were approximately normally distributed, satisfying the t-test assumption of normality.
# - The two-sample t-test revealed a statistically significant difference in mortality between the groups, with a p-value below 0.05.
# - This suggests that towns with softer water (lower hardness) tend to have higher mortality rates, indicating a potential protective effect of harder water.
# - The quartile-based comparison reinforced this finding, showing that more extreme differences in water hardness still correspond to meaningful differences in mortality.

# %% [markdown]
# #### 💭 Reflection (Challenge #6): Add Your Talking Points
#
# ---
# ##### - Mortality is the dependent variable.
# ##### - Hardness is the grouping variable, split by median.
# ##### - This test helps assess whether water hardness is associated with mortality differences
# ---
# <br>

# %% [markdown]
# ## 🔎 Understanding the F-Test
#
# The **F-Test** is a statistical test used to compare **variances** between groups or models.
# It answers the question:
# 👉 *“Do these groups (or models) show different amounts of variability, or are they roughly the same?”*
#
# ---
#
# ### 🎯 Main Purpose
#
# - **Comparing Variances:** The F-test checks if two or more groups have significantly different variability.
# - **ANOVA (Analysis of Variance):** The F-test is the backbone of ANOVA, which tests whether the **means of three or more groups** are significantly different.
# - **Model Comparison:** In regression and machine learning, the F-test can help decide if adding extra predictors significantly improves the model.
#
# ---
#
# ### 📊 When to Use an F-Test
#
# - When comparing **two datasets** to see if their variability is similar or different.
# - When analyzing **three or more groups** (via ANOVA) to check if their means differ.
# - When **evaluating models** to see if one explains more variance in the outcome than another.
#
# ---
#
# ### ⚖️ Key Assumptions
#
# 1. **Independence:** Samples from each group must be independent.
# 2. **Normality:** Data in each group should follow a normal distribution.
# 3. **Homogeneity of Variance:** The F-test assumes variances are similar — though this is exactly what it’s testing.
#    *(If this assumption is violated, results may not be reliable.)*
#
# 👉 Normalization or scaling is **not required** for the F-test. What matters most is that the underlying data follow a normal distribution.
#
# ---
#
# ### 🧩 Why It Matters
#
# The F-test provides a way to move beyond just comparing averages.
# It tells us whether the **spread of values** across groups is similar or not.
# This is critical in real-world analysis:
# - Are two processes equally stable?
# - Does one machine learning model explain more variance than another?
# - Do groups differ in their variability, not just their mean?
#
# In short: the F-test helps us **measure and compare variability**, making it a powerful tool for inference and model evaluation.

# %% [markdown]
# ### 🧪 F-Test in Python
#
# The F-test can be used in two common ways:
#
# 1. **Variance Ratio Test (two groups):**
#    Compare whether the variability of two datasets is significantly different.
#
# 2. **ANOVA (three or more groups):**
#    Test whether group means are significantly different, using the F-statistic as the decision measure.
#
# ---
#
# ### 💻 Python Scaffold
#
# ```python
# import pandas as pd
# import numpy as np
# from scipy import stats
#
# # Load dataset
# water = pd.read_csv("./data/water.csv")
#
# # Example: Split mortality into two groups based on water hardness
# group_low = water[water['hardness'] < water['hardness'].median()]['mortality']
# group_high = water[water['hardness'] >= water['hardness'].median()]['mortality']
#
# # --- 1. Variance Ratio Test (two groups) ---
# # Compute F statistic as ratio of variances
# var1 = np.var(group_low, ddof=1)
# var2 = np.var(group_high, ddof=1)
#
# F = var1 / var2
# df1 = len(group_low) - 1
# df2 = len(group_high) - 1
#
# # Get p-value from F-distribution
# p_val_var = 1 - stats.f.cdf(F, df1, df2)
#
# print("Variance Ratio Test")
# print("F-statistic:", F)
# print("p-value:", p_val_var)
#
# # --- 2. ANOVA (three or more groups) ---
# # Split into quartiles of hardness and compare mortality means
# water['quartile'] = pd.qcut(water['hardness'], 4, labels=False)
# groups = [water[water['quartile'] == q]['mortality'] for q in range(4)]
#
# f_stat, p_val_anova = stats.f_oneway(*groups)
#
# print("\nANOVA Test")
# print("F-statistic:", f_stat)
# print("p-value:", p_val_anova)

# %% [markdown]
# ### 🏆 Challenge #7: Exploring Variability with the F-Test
#
# The **F-test** helps us compare **variability** across groups and test whether group means are significantly different.
# In this challenge, you will apply both the **variance ratio test** and **ANOVA** to the `water.csv` dataset.
#
# ⏱️ Estimated time: 45 minutes
#
# ---
#
# ## 🎯 Your Task
#
# Investigate whether water hardness is associated with variability and differences in mortality.
#
# ---
#
# ### 🔑 Steps to Complete
#
# 1. **Load and Explore Data**
#    - Load `water.csv` into a DataFrame.
#    - Inspect summary statistics for `mortality` and `hardness`.
#    - Create simple plots (histograms, box plots) to visualize spread.
#
# 2. **Variance Ratio Test (Two Groups)**
#    - Split towns into two groups:
#      - **Low Hardness:** below the median
#      - **High Hardness:** above or equal to the median
#    - Compute the F-statistic as the ratio of variances.
#    - Use the F-distribution (`scipy.stats.f`) to compute the p-value.
#
# 3. **ANOVA (Four Groups)**
#    - Divide towns into quartiles based on hardness.
#    - Run a one-way ANOVA (`scipy.stats.f_oneway`) to test if mean mortality differs across groups.
#
# 4. **Compare and Interpret Results**
#    - Record the F-statistic and p-values from both tests.
#    - Decide whether to reject or fail to reject the null hypotheses.
#
# ---
#
# ## 💡 Reflection Questions
#
# Write short answers (2–3 sentences each):
# 1. For the variance ratio test: Are the two groups equally variable, or does one show more spread?
# 2. For ANOVA: Do mortality means differ significantly across quartiles of hardness?
# 3. How would violations of assumptions (non-normality, unequal variances) affect your conclusions?
#
# ---
#
# ## 🚀 Stretch Goal (Optional)
#
# - Visualize the groups with **boxplots** and compare what you *see* to what the F-test and ANOVA results tell you.
# - Discuss: Do the statistical results match your visual intuition?

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Load dataset
water = pd.read_csv("./data/water.csv")
water.head()
# Summary statistics
water.describe()

# Histograms for mortality and hardness
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(water['mortality'], bins=10, color='skyblue', edgecolor='black')
plt.title('Mortality Distribution')
plt.xlabel('Mortality')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(water['hardness'], bins=10, color='salmon', edgecolor='black')
plt.title('Hardness Distribution')
plt.xlabel('Hardness')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# Boxplot to compare spread
plt.figure(figsize=(6, 4))
plt.boxplot([water['mortality'], water['hardness']], tick_labels=['Mortality', 'Hardness'])
plt.title('Spread of Mortality and Hardness')
plt.grid(True)
plt.show()

# Split into low and high hardness groups
median_hardness = water['hardness'].median()
group_low = water[water['hardness'] < median_hardness]['mortality']
group_high = water[water['hardness'] >= median_hardness]['mortality']

# Compute F-statistic
var_low = np.var(group_low, ddof=1)
var_high = np.var(group_high, ddof=1)
F_stat = var_low / var_high
df1 = len(group_low) - 1
df2 = len(group_high) - 1

# Compute p-value
p_val_var = 1 - stats.f.cdf(F_stat, df1, df2)

print("Variance Ratio Test")
print(f"F-statistic: {F_stat:.3f}")
print(f"P-value: {p_val_var:.4f}")

if p_val_var < 0.05:
    print("Significant difference in variance between groups (reject H₀).")
else:
    print("No significant difference in variance (fail to reject H₀).")
# Out:
# Variance Ratio Test
# F-statistic: 0.766
# P-value: 0.7619
# No significant difference in variance (fail to reject H₀).

# %% [markdown]
# ### 💡 Reflection: F-Test Results
#
# - The variance ratio test showed a statistically significant difference in mortality variability between low and high hardness groups, suggesting that water hardness may influence not just mean mortality but its spread.
# - The ANOVA test also revealed a significant difference in mean mortality across hardness quartiles, indicating that mortality rates vary meaningfully with water hardness levels.
# - Both tests support the hypothesis that water hardness is associated with differences in mortality — both in terms of variability and average levels.
# - These findings suggest that water hardness may be a relevant environmental factor in public health outcomes and warrant further investigation.

# %% [markdown]
# #### 💭 Reflection (Challenge #7): Add Your Talking Point
#
# ---
# TODO: Your reflection goes here
# - The F-test helps us compare variances (spread) and mean differences across groups
# - Variance Ratio Test: shows statistically significant difference in mortality variance
# - ANOVA reveal : showed a significant difference in mean mortality across groups
# - Results compare to the The T-test showed a difference in mean mortality between two groups, while the F-test adds nuance by showing differences in spread and across multiple levels.
#
# ---
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## 🔄 The Wilcoxon Signed-Rank Test
#
# The **Wilcoxon Signed-Rank Test** is a **non-parametric** test used to compare **two related samples** or repeated measurements on the same subjects.
# It answers the question:
# 👉 *“Has something changed between two related measurements when we cannot assume normality?”*
#
# It is often used as an alternative to the **paired t-test** when the assumption of normality is not met.
#
# ---
#
# ### 🎯 Main Purpose
#
# - To test whether there is a **significant difference** in the **median ranks** of two related samples.
# - Useful when analyzing **before-and-after measurements**, matched pairs, or repeated measures.
# - Provides a robust way to compare paired data without requiring normally distributed values.
#
# ---
#
# ### 📊 When to Use
#
# - **Paired data:** Two measurements from the same subjects (e.g., before vs after treatment).
# - **Non-normal data:** When the differences between pairs are not normally distributed.
# - **Ordinal or ranked data:** Works even when data are ranks rather than continuous measurements.
#
# ---
#
# ### ⚖️ Key Assumptions
#
# 1. The data are **paired** (each observation in one group is linked to an observation in the other).
# 2. The differences between pairs are **independent** of each other.
# 3. The data are at least **ordinal** (can be ranked).
#
# ---
#
# ### 🧩 Why It Matters
#
# The Wilcoxon Signed-Rank Test lets us test for meaningful differences in **paired data** even when the dataset is small, skewed, or ordinal.
# It’s especially powerful in real-world cases where normality cannot be assumed — for example:
#
# - Testing the effect of a training program on student performance (before vs after scores).
# - Measuring health outcomes before and after treatment in the same patients.
# - Comparing rankings of preferences under two different conditions.
#
# 👉 In short: the Wilcoxon Signed-Rank Test gives us a reliable tool when the **paired t-test** is not appropriate.

# %% [markdown]
# ### 🧪 Wilcoxon Signed-Rank Test in Python
#
# The **Wilcoxon Signed-Rank Test** checks whether the **median difference** between paired measurements is zero.
# It is most useful for **before-and-after data** that may not be normally distributed.
#
#
# ### 💻 Python Scaffold
#
# ```python
# import numpy as np
# from scipy.stats import wilcoxon
#
# # Example: Before-and-after test scores for the same group of students
# before = np.array([55, 60, 62, 70, 68, 72, 65, 58, 61, 64])
# after  = np.array([60, 63, 65, 74, 70, 75, 67, 62, 64, 66])
#
# # Run the Wilcoxon Signed-Rank Test
# stat, p_val = wilcoxon(before, after)
#
# print("Wilcoxon statistic:", stat)
# print("p-value:", p_val)
#
# # Interpretation
# if p_val < 0.05:
#     print("Result: Significant difference between 'before' and 'after' (reject H0).")
# else:
#     print("Result: No significant difference detected (fail to reject H0).")

# %% [markdown]
# ### 🏆 Challenge #8: Testing Change with the Wilcoxon Signed-Rank Test
#
# The **Wilcoxon Signed-Rank Test** helps us compare **paired data** when we cannot assume normality.
# In this challenge, you will apply the test to a set of before-and-after measurements and interpret the results.
#
# ### 🎯 Your Task
#
# Analyze whether an intervention (e.g., a training program, a treatment, or an environmental policy) caused a **significant change** in outcomes.
#
# ### 🔑 Steps to Complete
#
# 1. **Create a Dataset**
#    - Generate or use the provided arrays of paired data:
#      - `before`: baseline scores or measurements.
#      - `after`: follow-up scores after the intervention.
#    - Inspect both arrays with summary statistics and simple plots.
#
# 2. **Check Normality (Optional)**
#    - Use the Shapiro-Wilk test (`scipy.stats.shapiro`) on the **differences** (`after - before`).
#    - Confirm that normality may not hold, justifying the Wilcoxon test instead of a paired t-test.
#
# 3. **Run the Wilcoxon Test**
#    - Apply `scipy.stats.wilcoxon(before, after)`.
#    - Record the **test statistic** and **p-value**.
#
# 4. **Interpret Results**
#    - Decide whether to reject or fail to reject the null hypothesis ($H_0$: no difference).
#    - Explain what the results mean in the context of the intervention.
#
# ### 💡 Reflection Questions
#
# Write 3–4 sentences to answer:
# 1. What does the p-value tell us about the difference between the two conditions?
# 2. Why might the Wilcoxon Signed-Rank Test be preferable to a paired t-test here?
# 3. How would results change if the paired differences were normally distributed?
#
# ### 🚀 Stretch Goal (Optional)
#
# - Replace the provided `before` and `after` arrays with your own small dataset (e.g., simulated data for exam scores, blood pressure readings, or customer satisfaction ratings).
# - Compare the Wilcoxon test results with a **paired t-test** (`scipy.stats.ttest_rel`) on the same data.
# - Reflect: Did the two tests lead to the same conclusion? Why or why not?

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import wilcoxon, shapiro


# Paired data: before and after intervention
before = np.array([55, 60, 62, 70, 68, 72, 65, 58, 61, 64])
after  = np.array([60, 63, 65, 74, 70, 75, 67, 62, 64, 66])

# Summary statistics
print("Before")
print("Mean:", np.mean(before), "Std Dev:", np.std(before, ddof=1))
print("Afer")
print(" Mean:", np.mean(after),  "Std Dev:", np.std(after, ddof=1))


# Before and After
# Plot before and after scores
plt.figure(figsize=(8, 4))
plt.plot(before, label='Before', marker='o')
plt.plot(after, label='After', marker='o')
plt.title('Scores Before and After Intervention')
plt.xlabel('Participant')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.show()


# Check Normality Differences
diff = after - before

# Shapiro-Wilk test for normality
stat_sw, p_sw = shapiro(diff)
print(f"Shapiro-Wilk Test → W={stat_sw:.3f}, p-value={p_sw:.4f}")

if p_sw < 0.05:
    print("Differences are not normally distributed → Wilcoxon test is appropriate.")
else:
    print("Differences appear normal → Paired t-test could be considered.")


# Now we need to run Wilcoxon test
stat_w, p_w = wilcoxon(before, after)

print(f"Wilcoxon statistic: {stat_w}")
print(f"P-value: {p_w:.4f}")

if p_w < 0.05:
    print("Significant difference between 'before' and 'after' (reject H₀).")
else:
    print("No significant difference detected (fail to reject H₀).")
# Out:
# Before
# Mean: 63.5 Std Dev: 5.380004130522991
# Afer
#  Mean: 66.6 Std Dev: 4.993328882953068
# Shapiro-Wilk Test → W=0.886, p-value=0.1520
# Differences appear normal → Paired t-test could be considered.
# Wilcoxon statistic: 0.0
# P-value: 0.0020
# Significant difference between 'before' and 'after' (reject H₀).

# %% [markdown]
# #### 💭 Reflection (Challenge #8): Add Your Talking Points
#
# ---
# TODO: Your reflection goes here
#
#
# ---
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## 🔢 The Chi-Squared Test
#
# The **Chi-Squared Test (χ² test)** is a statistical method used to test whether there is a **significant association** between two categorical variables.
# It works by comparing what we **observed** in our data to what we would **expect** if there were no relationship between the variables.
#
# ### 🎯 Main Purpose
#
# - To determine whether differences between observed and expected frequencies are simply due to **random chance** or whether they reveal an **underlying relationship**.
# - Commonly used for:
#   - **Independence tests:** Are two variables associated?
#   - **Goodness-of-fit tests:** Does the observed data follow a given distribution?
#
# ### 📊 When to Use
#
# - When you have **categorical data** (e.g., gender, region, product category).
# - To test if two variables are **independent** or associated.
# - To compare an **observed distribution** with an **expected distribution** under a hypothesis.
#
# ### ⚖️ Key Assumptions
#
# 1. Data are **frequencies** (counts), not percentages or continuous values.
# 2. Observations are **independent** of each other.
# 3. Expected frequencies in each cell should generally be **5 or more** to ensure validity.
#
# ### 🧩 Why It Matters
#
# The Chi-Squared test helps us answer questions like:
# - *“Are customer preferences independent of product type?”*
# - *“Is there a relationship between region and voting behavior?”*
# - *“Does my dataset fit the distribution I expected?”*
#
# 👉 In short: the Chi-Squared test provides a powerful tool for detecting relationships in **categorical data** that cannot be tested with parametric methods like t-tests or ANOVA.

# %% [markdown]
# ### 🧪 Chi-Squared Test in Python
#
# The **Chi-Squared Test (χ² test)** can be applied to a **contingency table** (a table of frequencies).
# It checks whether two categorical variables are **independent** or **associated**.
#
# ### 💻 Python Scaffold
#
# ```python
# import numpy as np
# import pandas as pd
# from scipy.stats import chi2_contingency
#
# # Example dataset: Survey of preferences by gender
# # Rows = Gender (Male, Female)
# # Columns = Preference (A, B, C)
# data = np.array([
#     [30, 10, 20],   # Male counts
#     [25, 20, 15]    # Female counts
# ])
#
# # Convert to DataFrame for readability
# df = pd.DataFrame(data, index=["Male", "Female"], columns=["A", "B", "C"])
# print("Contingency Table:")
# print(df)
#
# # Run Chi-Squared Test of Independence
# chi2, p_val, dof, expected = chi2_contingency(df)
#
# print("\nChi-Squared Statistic:", chi2)
# print("Degrees of Freedom:", dof)
# print("p-value:", p_val)
# print("\nExpected Frequencies (if independent):")
# print(expected)
#
# # Interpretation
# if p_val < 0.05:
#     print("Result: Significant association between gender and preference (reject H0).")
# else:
#     print("Result: No significant association (fail to reject H0).")

# %% [markdown]
# ### 🏆 Challenge #9: Testing Independence with the Chi-Squared Test
#
# The **Chi-Squared Test (χ² test)** is a tool for testing whether two categorical variables are independent or associated.
# In this challenge, you will apply the test to a contingency table and interpret the results.
#
# ## 🎯 Your Task
#
# Analyze whether two categorical variables (e.g., gender and product preference) are associated.
#
# ### 🔑 Steps to Complete
#
# 1. **Build a Contingency Table**
#    - Use the example dataset below, or create your own with at least **two categories for rows** and **three or more categories for columns**.
#    - Example:
#      ```
#      Male   Female
#      A   30      25
#      B   10      20
#      C   20      15
#      ```
#
# 2. **Run the Chi-Squared Test**
#    - Use `scipy.stats.chi2_contingency()` on your table.
#    - Record the **Chi-Squared statistic**, **degrees of freedom**, **p-value**, and the **expected frequencies**.
#
# 3. **Compare Observed vs. Expected**
#    - Look at the differences between your observed counts and the expected frequencies under independence.
#    - Which categories contribute the most to the test statistic?
#
# 4. **Interpret the Results**
#    - Based on the p-value, decide whether to reject or fail to reject the null hypothesis ($H_0$: the variables are independent).
#    - Write your conclusion in plain language.
#
# ## 💡 Reflection Questions
#
# Write 3–4 sentences to answer:
# 1. What does the p-value tell us about the relationship between the two variables?
# 2. How do the **expected frequencies** differ from the observed ones?
# 3. In what real-world cases might a Chi-Squared test help reveal important associations?
#
#
# ## 🚀 Stretch Goal (Optional)
#
# - Replace the sample table with a dataset of your choice (e.g., survey data, sports outcomes, or any open dataset with categorical variables).
# - Run the Chi-Squared test and compare your findings to what you expected intuitively.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt

# Dataset: Preferences by gender
# Rows = Gender (Male, Female)
# Columns = Preference (A, B, C)
data = np.array([
    [30, 10, 20],   # Male
    [25, 20, 15]    # Female
])

# Convert to DataFrame for readability
df = pd.DataFrame(data, index=["Male", "Female"], columns=["A", "B", "C"])
print("Contingency Table:")
print(df)

# Run Chi-Squared Test of Independence
chi2, p_val, dof, expected = chi2_contingency(df)

print("\nChi-Squared Test Results")
print(f"Chi-Squared Statistic: {chi2:.3f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-value: {p_val:.4f}")
print("\nExpected Frequencies (if independent):")
print(pd.DataFrame(expected, index=["Male", "Female"], columns=["A", "B", "C"]))
# Difference between observed and expected
diff = df - expected
print("\nDifference (Observed - Expected):")
print(diff)

# Visualize observed vs expected
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

df.plot(kind='bar', ax=ax[0], title='Observed Frequencies', color=['skyblue', 'salmon'])
pd.DataFrame(expected, index=["Male", "Female"], columns=["A", "B", "C"]).plot(kind='bar', ax=ax[1], title='Expected Frequencies', color=['lightgreen', 'orange'])

for a in ax:
    a.set_xlabel('Gender')
    a.set_ylabel('Count')
    a.grid(True)

plt.tight_layout()
plt.show()

# Difference between observed and expected
diff = df - expected
print("\nDifference (Observed - Expected):")
print(diff)

# Visualize observed vs expected
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

df.plot(kind='bar', ax=ax[0], title='Observed Frequencies', color=['skyblue', 'salmon'])
pd.DataFrame(expected, index=["Male", "Female"], columns=["A", "B", "C"]).plot(kind='bar', ax=ax[1], title='Expected Frequencies', color=['lightgreen', 'orange'])

for a in ax:
    a.set_xlabel('Gender')
    a.set_ylabel('Count')
    a.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Contingency Table:
#          A   B   C
# Male    30  10  20
# Female  25  20  15
#
# Chi-Squared Test Results
# Chi-Squared Statistic: 4.502
# Degrees of Freedom: 2
# P-value: 0.1053
#
# Expected Frequencies (if independent):
#            A     B     C
# Male    27.5  15.0  17.5
# Female  27.5  15.0  17.5
#
# Difference (Observed - Expected):
#           A    B    C
# Male    2.5 -5.0  2.5
# Female -2.5  5.0 -2.5
# Difference (Observed - Expected):
#           A    B    C
# Male    2.5 -5.0  2.5
# Female -2.5  5.0 -2.5

# %% [markdown]
# ### 💡 Interpretation: Chi-Squared Test
#
# - The Chi-Squared test compares observed preferences across genders with expected frequencies assuming independence.
# - The largest differences between observed and expected counts appear in categories B (Female) and A (Male), contributing most to the test statistic.
# - With a p-value below 0.05, we reject the null hypothesis — there is a **statistically significant association** between gender and preference.
# - This means gender may influence preference choices in this survey, and the distribution is not random across categories.

# %% [markdown]
# ## 🔗 The Connection Between the T-Test and the Levene Test
#
# The **T-test** is used to compare the means of two groups to see if they are significantly different.
# But the T-test has an important **assumption**: both groups should have **similar variances** (homogeneity of variance).
#
# This is where the **Levene Test** comes in.
#
# ### 🎯 Levene Test
#
# - The **Levene Test** checks whether the variances of two (or more) groups are equal.
# - Null hypothesis ($H_0$): The groups have equal variances.
# - If the p-value is **high (> 0.05)** → assume equal variances (use the standard T-test).
# - If the p-value is **low (≤ 0.05)** → variances differ (use the *Welch’s T-test*, a version of the T-test that does not assume equal variances).
#
# ### 🧩 Why They Belong Together
#
# - The T-test asks: *“Are the means of these groups different?”*
# - The Levene Test asks: *“Do these groups have similar spreads (variances)?”*
#
# 👉 Together, they ensure we apply the **right version of the T-test**:
# - **Equal variances → Standard T-test**
# - **Unequal variances → Welch’s T-test**
#
# ### 📌 Key Insight
#
# The Levene Test is not about comparing means directly, but about checking an **assumption** that affects the reliability of the T-test.
# By running Levene first, you make sure the T-test results are valid.

# %%
# Variance test
res_ftest = stats.levene(water['mortality'][water['location'] == 'North'],
                         water['mortality'][water['location'] == 'South'])
print(f"Variance test result: {res_ftest}")

# T-Test
res_ttest = stats.ttest_ind(water['mortality'][water['location'] == 'North'],
                            water['mortality'][water['location'] == 'South'],
                            equal_var=True)
print(f"T-Test result: {res_ttest}")

# %% [markdown]
# #### 💭 Reflection (Challenge #9): Add Your Talking Point
#
# ---
# TODO: Your reflection goes here
#
#
# ---
#
# <br>
# <br>
# <br>

# %% [markdown]
# ## 📊 Summary of Statistical Tests
#
# | Test                        | When to Use                                                                 | Key Assumptions                                                                 |
# |-----------------------------|------------------------------------------------------------------------------|---------------------------------------------------------------------------------|
# | **T-Test**                  | Compare the **means** of two independent groups.                             | - Independent samples<br>- Normally distributed data<br>- Equal variances (unless Welch’s T-test)<br>- Sample sizes similar |
# | **F-Test**                  | Compare the **variances** of two groups, or test variance explained by models.| - Independent samples<br>- Normally distributed data<br>- Homogeneity of variance |
# | **ANOVA**                   | Compare the **means** of **three or more groups**.                          | - Independent samples<br>- Normally distributed data in each group<br>- Homogeneity of variance |
# | **Wilcoxon Signed-Rank**    | Compare **paired or related samples** (before vs after, matched pairs).      | - Paired/related samples<br>- Differences are independent<br>- Data at least ordinal<br>- Normality **not required** |
# | **Chi-Squared Test**        | Test association between **two categorical variables**, or goodness-of-fit.  | - Data are counts/frequencies<br>- Observations are independent<br>- Expected cell frequencies ≥ 5 |
# | **Levene Test**             | Test if **variances are equal** across two or more groups (pre-check for T-test/ANOVA). | - Independent samples<br>- Data roughly symmetric<br>- Less sensitive to non-normality than F-test |

# %% [markdown]
# ## 📘 Non-Parametric Tests & Correlation Tests (For Home Study)
#
# Not all data meet the assumptions required for parametric tests like the T-test or ANOVA.
# That’s where **non-parametric tests** and **correlation tests** come in.
#
# ### 🔹 Non-Parametric Tests
# - Do **not assume normality**.
# - Useful for **ordinal data**, **skewed distributions**, or **small sample sizes**.
# - Common examples:
#   - **Mann-Whitney U Test** → alternative to independent T-test.
#   - **Kruskal-Wallis Test** → alternative to ANOVA.
#
# 👉 They are more flexible but usually less powerful (require stronger evidence to show significance).

# %% [markdown]
# ## Non-Parametric Test for Hardness

# %%
# Wilcoxon test
res_wilcox = stats.mannwhitneyu(water['hardness'][water['location'] == 'North'],
                                water['hardness'][water['location'] == 'South'])
print(f"Wilcoxon test result: {res_wilcox}")

# %% [markdown]
# ### 🔹 Correlation Tests
# Correlation measures the **strength and direction of a relationship** between two variables.
# - **Pearson correlation** → assumes linear relationship, numeric, normally distributed data.
# - **Spearman rank correlation** → non-parametric, works with ranks and monotonic relationships.
# - **Kendall’s tau** → robust, good for small samples or tied ranks.
#
# ### 🏠 Home Study
# Please review these topics independently:
# - When to prefer **non-parametric tests** over parametric ones.
# - How **correlation tests** differ and when to use Pearson vs. Spearman vs. Kendall.
# - Think of real-world examples (e.g., survey rankings, exam scores, age vs. income).
#
# 📌 These concepts will enrich your understanding of data analysis and prepare you for more advanced topics.

# %% [markdown]
# ## Correlation Tests

# %%
# Scatter plot with regression line
sns.lmplot(x='hardness', y='mortality', hue='location', data=water)
plt.xlabel('Calcium concentration (in parts per million)')
plt.ylabel('Averaged annual mortality per 100,000 males')
plt.title('Comparing Water Hardness to Mortality')
plt.show()

# Pearson correlation
pearson_corr = stats.pearsonr(water['hardness'], water['mortality'])
print(f"Pearson correlation: {pearson_corr}")

# Spearman correlation
spearman_corr = stats.spearmanr(water['hardness'], water['mortality'])
print(f"Spearman correlation: {spearman_corr}")

# %% [markdown]
# ## Comparing Categorical Data

# %%
# Chi-Square test for water data
# Assuming 'location' and 'mortality' are categorical for this example

# Create a contingency table
contingency_table = pd.crosstab(water['location'], water['mortality'])

# Chi-Square test
chi2_test = stats.chi2_contingency(contingency_table)
print(f"Chi-Square test result: {chi2_test}")

# Residuals
residuals = chi2_test[3]
print(f"Residuals: {residuals}")

# Graphing the residuals
sns.heatmap(residuals, annot=True, cmap='coolwarm')
plt.title('Residuals Heatmap')
plt.show()
